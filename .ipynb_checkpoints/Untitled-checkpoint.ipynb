# %%
from pprint import pprint
from dotenv import find_dotenv, dotenv_values
from pymongo import MongoClient

# %%
config = dotenv_values(find_dotenv())
conn_str = config["mongodb_dev"]

# %%
client = MongoClient(conn_str)
print(client.list_database_names())
# Out:
# ['fake-issuer', 'flow-api', 'flow-auth', 'flow-backoffice', 'flow-delivery', 'flow-distribution', 'flow-engagement', 'flow-ingestion', 'flow-merchant-repository', 'flow-receipt-vault', 'flow_receipt_vault', 'admin', 'local']

# %%
backoffice_db = client["flow-backoffice"]
print(backoffice_db.list_collection_names())
# Out:
# ['Reward', 'Issuer', 'ReceiptMetadataFieldMapping', 'MccToMcgMapping', 'Merchant', 'Playbook', 'Asset', 'MccToMcgMappingTemplate', 'Acquirer', 'ApiAuthentication', 'EngagementTemplate', 'MongockChangeLog', 'ScoringConversion', 'MCGMappingTemplate', 'RewardTemplate', 'ReceiptViewerLookAndFeel', 'MCGMapping', 'Engagement', 'Store', 'TransactionFeedFieldMapping', 'WidgetTemplate', 'SystemAccount', 'ApiConfiguration', 'WebHookConfiguration', 'IssuerReceiptViewerTransformKey', 'IssuerBranding', 'Rule', 'MongockLock']

# %%
issuer = backoffice_db.Issuer.find_one()
pprint(issuer)
# Out:
# {'_class': 'io.flownetworks.issuer.entity.IssuerEntity',
#  '_id': ObjectId('604e2ccd8f162060197661d0'),
#  'code': 'VISA_GO',
#  'countryCode': 'SG',
#  'createdBy': 'system',
#  'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 44, 319000),
#  'engagementBrief': {'_class': 'io.flownetworks.common.entity.AssetEntity',
#                      '_id': '3d2bb3a9-792e-4eb7-a5e9-69da1f88121e',
#                      'code': 'engagement_brief',
#                      'createdBy': 'system',
#                      'createdDate': datetime.datetime(2021, 5, 5, 15, 4, 30, 923000),
#                      'lastModifiedBy': 'system',
#                      'lastModifiedDate': datetime.datetime(2021, 8, 16, 8, 36, 30, 916000),
#                      'name': 'Engagement Brief',
#                      'owner': 'Platform',
#                      'type': 'Engagement'},
#  'languages': [{'code': 'ja', 'isDefault': False},
#                {'code': 'en', 'isDefault': True}],
#  'lastModifiedBy': 'system',
#  'lastModifiedDate': datetime.datetime(2021, 8, 16, 8, 36, 30, 916000),
#  'masterPage': {'_class': 'io.flownetworks.common.entity.AssetEntity',
#                 '_id': ObjectId('6081a8242a1a9f71ca89439b'),
#                 'code': 'master_page',
#                 'createdBy': 'system',
#                 'createdDate': datetime.datetime(2021, 4, 22, 16, 45, 24, 243000),
#                 'lastModifiedBy': 'system',
#                 'lastModifiedDate': datetime.datetime(2021, 8, 16, 8, 36, 30, 916000),
#                 'name': "Visa Go's master page",
#                 'owner': 'Platform',
#                 'type': 'Engagement'},
#  'name': 'Visa Go TTTTT-444',
#  'playbooks': [{'_class': 'io.flownetworks.playbook.entity.PlaybookEntity',
#                 '_id': ObjectId('6081a80b2a1a9f71ca894373'),
#                 'createdBy': 'system',
#                 'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 59, 220000),
#                 'endTime': datetime.datetime(2021, 7, 31, 15, 0),
#                 'lastModifiedBy': 'system',
#                 'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 59, 220000),
#                 'name': '#1 Product: Payment Reward',
#                 'rewardColor': '#FFE000',
#                 'rewards': [{'_class': 'io.flownetworks.reward.entity.RewardEntity',
#                              '_id': ObjectId('6081a8082a1a9f71ca89436a'),
#                              'createdBy': 'system',
#                              'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 603000),
#                              'data': {},
#                              'lastModifiedBy': 'system',
#                              'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 603000),
#                              'name': 'Bronze',
#                              'status': 'Active',
#                              'type': 'Badge'}],
#                 'rules': [{'_class': 'io.flownetworks.playbook.entity.RuleEntity',
#                            '_id': ObjectId('6081a80d2a1a9f71ca894379'),
#                            'createdBy': 'system',
#                            'createdDate': datetime.datetime(2021, 4, 22, 16, 45, 1, 501000),
#                            'expression': '---\n'
#                                          'name: Payment Reward Rule\n'
#                                          'description: Rule for Payment '
#                                          'Reward\n'
#                                          'priority: 1\n'
#                                          'condition: "ActivityKind.Transaction '
#                                          '== input.kind"\n'
#                                          'actions:\n'
#                                          '  - '
#                                          '"output.add(\\"6081a8082a1a9f71ca89436a\\")"',
#                            'kind': 'Transaction',
#                            'lastModifiedBy': 'system',
#                            'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 45, 1, 501000),
#                            'name': '#1 Product: Payment Reward Rule'}],
#                 'startTime': datetime.datetime(2021, 6, 30, 15, 0),
#                 'status': 'Active',
#                 'type': 'Payment'},
#                {'_class': 'io.flownetworks.playbook.entity.PlaybookEntity',
#                 '_id': ObjectId('6081a80b2a1a9f71ca894374'),
#                 'createdBy': 'system',
#                 'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 59, 229000),
#                 'endTime': datetime.datetime(2021, 7, 31, 15, 0),
#                 'engagements': [{'_class': 'io.flownetworks.engagement.entity.EngagementEntity',
#                                  '_id': ObjectId('6081a8072a1a9f71ca894360'),
#                                  'code': 'trivia',
#                                  'createdBy': 'system',
#                                  'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 196000),
#                                  'data': {'goalRewardName': None,
#                                           'inProgress': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                          'description': 'Earn '
#                                                                         'more '
#                                                                         'when '
#                                                                         'you '
#                                                                         'spend. '
#                                                                         'Make '
#                                                                         '$remainingLevels '
#                                                                         'more '
#                                                                         'payment(s) '
#                                                                         'of '
#                                                                         '$minQualifyingAmount '
#                                                                         'or '
#                                                                         'more '
#                                                                         'at '
#                                                                         '$qualifyingMerchantName '
#                                                                         'to '
#                                                                         'earn '
#                                                                         '$goalRewardName',
#                                                          'title': 'Punch and '
#                                                                   'win'},
#                                           'loaded': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                      'description': 'Earn more '
#                                                                     'when you '
#                                                                     'spend. '
#                                                                     'Make '
#                                                                     '$remainingLevels '
#                                                                     'more '
#                                                                     'payment(s) '
#                                                                     'of '
#                                                                     '$minQualifyingAmount '
#                                                                     'or more '
#                                                                     'at '
#                                                                     '$qualifyingMerchantName '
#                                                                     'to earn '
#                                                                     '$goalRewardName',
#                                                      'title': 'Punch and win'},
#                                           'qualifyingMerchantName': None},
#                                  'expiredInSeconds': 480,
#                                  'lastModifiedBy': 'system',
#                                  'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 196000),
#                                  'name': 'Trivia',
#                                  'type': 'SkillBased'},
#                                 {'_class': 'io.flownetworks.engagement.entity.EngagementEntity',
#                                  '_id': ObjectId('6081a8072a1a9f71ca894361'),
#                                  'code': 'hoop_shot',
#                                  'createdBy': 'system',
#                                  'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 562000),
#                                  'data': {'goalRewardName': None,
#                                           'inProgress': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                          'description': 'Earn '
#                                                                         'more '
#                                                                         'when '
#                                                                         'you '
#                                                                         'spend. '
#                                                                         'Make '
#                                                                         '$remainingLevels '
#                                                                         'more '
#                                                                         'payment(s) '
#                                                                         'of '
#                                                                         '$minQualifyingAmount '
#                                                                         'or '
#                                                                         'more '
#                                                                         'at '
#                                                                         '$qualifyingMerchantName '
#                                                                         'to '
#                                                                         'earn '
#                                                                         '$goalRewardName',
#                                                          'title': 'Punch and '
#                                                                   'win'},
#                                           'loaded': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                      'description': 'Earn more '
#                                                                     'when you '
#                                                                     'spend. '
#                                                                     'Make '
#                                                                     '$remainingLevels '
#                                                                     'more '
#                                                                     'payment(s) '
#                                                                     'of '
#                                                                     '$minQualifyingAmount '
#                                                                     'or more '
#                                                                     'at '
#                                                                     '$qualifyingMerchantName '
#                                                                     'to earn '
#                                                                     '$goalRewardName',
#                                                      'title': 'Punch and win'},
#                                           'qualifyingMerchantName': None},
#                                  'expiredInSeconds': 480,
#                                  'lastModifiedBy': 'system',
#                                  'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 562000),
#                                  'name': 'Hoop Shot',
#                                  'type': 'SkillBased'},
#                                 {'_class': 'io.flownetworks.engagement.entity.EngagementEntity',
#                                  '_id': ObjectId('6081a8072a1a9f71ca894362'),
#                                  'code': 'speed_climber',
#                                  'createdBy': 'system',
#                                  'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 564000),
#                                  'data': {'goalRewardName': None,
#                                           'inProgress': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                          'description': 'Earn '
#                                                                         'more '
#                                                                         'when '
#                                                                         'you '
#                                                                         'spend. '
#                                                                         'Make '
#                                                                         '$remainingLevels '
#                                                                         'more '
#                                                                         'payment(s) '
#                                                                         'of '
#                                                                         '$minQualifyingAmount '
#                                                                         'or '
#                                                                         'more '
#                                                                         'at '
#                                                                         '$qualifyingMerchantName '
#                                                                         'to '
#                                                                         'earn '
#                                                                         '$goalRewardName',
#                                                          'title': 'Punch and '
#                                                                   'win'},
#                                           'loaded': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                      'description': 'Earn more '
#                                                                     'when you '
#                                                                     'spend. '
#                                                                     'Make '
#                                                                     '$remainingLevels '
#                                                                     'more '
#                                                                     'payment(s) '
#                                                                     'of '
#                                                                     '$minQualifyingAmount '
#                                                                     'or more '
#                                                                     'at '
#                                                                     '$qualifyingMerchantName '
#                                                                     'to earn '
#                                                                     '$goalRewardName',
#                                                      'title': 'Punch and win'},
#                                           'qualifyingMerchantName': None},
#                                  'expiredInSeconds': 480,
#                                  'lastModifiedBy': 'system',
#                                  'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 564000),
#                                  'name': 'Speed Climber',
#                                  'type': 'SkillBased'},
#                                 {'_class': 'io.flownetworks.engagement.entity.EngagementEntity',
#                                  '_id': ObjectId('6081a8072a1a9f71ca894363'),
#                                  'code': 'bmx_king',
#                                  'createdBy': 'system',
#                                  'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 565000),
#                                  'data': {'goalRewardName': None,
#                                           'inProgress': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                          'description': 'Earn '
#                                                                         'more '
#                                                                         'when '
#                                                                         'you '
#                                                                         'spend. '
#                                                                         'Make '
#                                                                         '$remainingLevels '
#                                                                         'more '
#                                                                         'payment(s) '
#                                                                         'of '
#                                                                         '$minQualifyingAmount '
#                                                                         'or '
#                                                                         'more '
#                                                                         'at '
#                                                                         '$qualifyingMerchantName '
#                                                                         'to '
#                                                                         'earn '
#                                                                         '$goalRewardName',
#                                                          'title': 'Punch and '
#                                                                   'win'},
#                                           'loaded': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                      'description': 'Earn more '
#                                                                     'when you '
#                                                                     'spend. '
#                                                                     'Make '
#                                                                     '$remainingLevels '
#                                                                     'more '
#                                                                     'payment(s) '
#                                                                     'of '
#                                                                     '$minQualifyingAmount '
#                                                                     'or more '
#                                                                     'at '
#                                                                     '$qualifyingMerchantName '
#                                                                     'to earn '
#                                                                     '$goalRewardName',
#                                                      'title': 'Punch and win'},
#                                           'qualifyingMerchantName': None},
#                                  'expiredInSeconds': 480,
#                                  'lastModifiedBy': 'system',
#                                  'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 565000),
#                                  'name': 'BMX King',
#                                  'type': 'SkillBased'},
#                                 {'_class': 'io.flownetworks.engagement.entity.EngagementEntity',
#                                  '_id': ObjectId('6081a8072a1a9f71ca894364'),
#                                  'code': 'flip_star',
#                                  'createdBy': 'system',
#                                  'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 566000),
#                                  'data': {'goalRewardName': None,
#                                           'inProgress': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                          'description': 'Earn '
#                                                                         'more '
#                                                                         'when '
#                                                                         'you '
#                                                                         'spend. '
#                                                                         'Make '
#                                                                         '$remainingLevels '
#                                                                         'more '
#                                                                         'payment(s) '
#                                                                         'of '
#                                                                         '$minQualifyingAmount '
#                                                                         'or '
#                                                                         'more '
#                                                                         'at '
#                                                                         '$qualifyingMerchantName '
#                                                                         'to '
#                                                                         'earn '
#                                                                         '$goalRewardName',
#                                                          'title': 'Punch and '
#                                                                   'win'},
#                                           'loaded': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                      'description': 'Earn more '
#                                                                     'when you '
#                                                                     'spend. '
#                                                                     'Make '
#                                                                     '$remainingLevels '
#                                                                     'more '
#                                                                     'payment(s) '
#                                                                     'of '
#                                                                     '$minQualifyingAmount '
#                                                                     'or more '
#                                                                     'at '
#                                                                     '$qualifyingMerchantName '
#                                                                     'to earn '
#                                                                     '$goalRewardName',
#                                                      'title': 'Punch and win'},
#                                           'qualifyingMerchantName': None},
#                                  'expiredInSeconds': 240,
#                                  'lastModifiedBy': 'system',
#                                  'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 566000),
#                                  'name': 'Flip Star',
#                                  'type': 'SkillBased'},
#                                 {'_class': 'io.flownetworks.engagement.entity.EngagementEntity',
#                                  '_id': ObjectId('6081a8072a1a9f71ca894365'),
#                                  'code': 'super_striker',
#                                  'createdBy': 'system',
#                                  'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 567000),
#                                  'data': {'goalRewardName': None,
#                                           'inProgress': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                          'description': 'Earn '
#                                                                         'more '
#                                                                         'when '
#                                                                         'you '
#                                                                         'spend. '
#                                                                         'Make '
#                                                                         '$remainingLevels '
#                                                                         'more '
#                                                                         'payment(s) '
#                                                                         'of '
#                                                                         '$minQualifyingAmount '
#                                                                         'or '
#                                                                         'more '
#                                                                         'at '
#                                                                         '$qualifyingMerchantName '
#                                                                         'to '
#                                                                         'earn '
#                                                                         '$goalRewardName',
#                                                          'title': 'Punch and '
#                                                                   'win'},
#                                           'loaded': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                      'description': 'Earn more '
#                                                                     'when you '
#                                                                     'spend. '
#                                                                     'Make '
#                                                                     '$remainingLevels '
#                                                                     'more '
#                                                                     'payment(s) '
#                                                                     'of '
#                                                                     '$minQualifyingAmount '
#                                                                     'or more '
#                                                                     'at '
#                                                                     '$qualifyingMerchantName '
#                                                                     'to earn '
#                                                                     '$goalRewardName',
#                                                      'title': 'Punch and win'},
#                                           'qualifyingMerchantName': None},
#                                  'expiredInSeconds': 480,
#                                  'lastModifiedBy': 'system',
#                                  'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 567000),
#                                  'name': 'Super Striker',
#                                  'type': 'SkillBased'},
#                                 {'_class': 'io.flownetworks.engagement.entity.EngagementEntity',
#                                  '_id': ObjectId('6081a8072a1a9f71ca894366'),
#                                  'code': 'bullseyes',
#                                  'createdBy': 'system',
#                                  'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 568000),
#                                  'data': {'goalRewardName': None,
#                                           'inProgress': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                          'description': 'Earn '
#                                                                         'more '
#                                                                         'when '
#                                                                         'you '
#                                                                         'spend. '
#                                                                         'Make '
#                                                                         '$remainingLevels '
#                                                                         'more '
#                                                                         'payment(s) '
#                                                                         'of '
#                                                                         '$minQualifyingAmount '
#                                                                         'or '
#                                                                         'more '
#                                                                         'at '
#                                                                         '$qualifyingMerchantName '
#                                                                         'to '
#                                                                         'earn '
#                                                                         '$goalRewardName',
#                                                          'title': 'Punch and '
#                                                                   'win'},
#                                           'loaded': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                      'description': 'Earn more '
#                                                                     'when you '
#                                                                     'spend. '
#                                                                     'Make '
#                                                                     '$remainingLevels '
#                                                                     'more '
#                                                                     'payment(s) '
#                                                                     'of '
#                                                                     '$minQualifyingAmount '
#                                                                     'or more '
#                                                                     'at '
#                                                                     '$qualifyingMerchantName '
#                                                                     'to earn '
#                                                                     '$goalRewardName',
#                                                      'title': 'Punch and win'},
#                                           'qualifyingMerchantName': None},
#                                  'expiredInSeconds': 480,
#                                  'lastModifiedBy': 'system',
#                                  'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 55, 568000),
#                                  'name': 'Bullseyes',
#                                  'type': 'SkillBased'}],
#                 'lastModifiedBy': 'system',
#                 'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 59, 229000),
#                 'name': '#2 Playbook: Tokyo 2021',
#                 'rewardColor': '#FFE000',
#                 'rewards': [{'_class': 'io.flownetworks.reward.entity.RewardEntity',
#                              '_id': ObjectId('6081a8082a1a9f71ca89436a'),
#                              'createdBy': 'system',
#                              'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 603000),
#                              'data': {},
#                              'lastModifiedBy': 'system',
#                              'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 603000),
#                              'name': 'Bronze',
#                              'status': 'Active',
#                              'type': 'Badge'},
#                             {'_class': 'io.flownetworks.reward.entity.RewardEntity',
#                              '_id': ObjectId('6081a8082a1a9f71ca89436b'),
#                              'createdBy': 'system',
#                              'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 887000),
#                              'data': {},
#                              'lastModifiedBy': 'system',
#                              'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 887000),
#                              'name': 'Silver',
#                              'status': 'Active',
#                              'type': 'Badge'},
#                             {'_class': 'io.flownetworks.reward.entity.RewardEntity',
#                              '_id': ObjectId('6081a8082a1a9f71ca89436c'),
#                              'createdBy': 'system',
#                              'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 888000),
#                              'data': {},
#                              'lastModifiedBy': 'system',
#                              'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 888000),
#                              'name': 'Gold',
#                              'status': 'Active',
#                              'type': 'Badge'}],
#                 'startTime': datetime.datetime(2021, 6, 30, 15, 0),
#                 'status': 'Active',
#                 'type': 'Engagement'},
#                {'_class': 'io.flownetworks.playbook.entity.PlaybookEntity',
#                 '_id': ObjectId('6081a80b2a1a9f71ca894375'),
#                 'createdBy': 'system',
#                 'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 59, 232000),
#                 'endTime': datetime.datetime(2021, 7, 31, 15, 0),
#                 'lastModifiedBy': 'system',
#                 'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 59, 232000),
#                 'name': '#3 Cross-Sell Voucher',
#                 'rewardColor': '#FFE000',
#                 'rewards': [{'_class': 'io.flownetworks.reward.entity.RewardEntity',
#                              '_id': ObjectId('6081a8082a1a9f71ca89436d'),
#                              'createdBy': 'system',
#                              'createdDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 889000),
#                              'data': {'discountType': 'FIXED_AMOUNT',
#                                       'display': {'_class': 'io.flownetworks.reward.entity.RewardDisplay',
#                                                   'displayName': 'Air Pass '
#                                                                  'Voucher',
#                                                   'displayValue': '0'},
#                                       'promoCode': 'N/A',
#                                       'rewardCollected': {'_class': 'io.flownetworks.reward.entity.RewardInfo',
#                                                           'title': 'Congratulations'},
#                                       'rewardReady': {'_class': 'io.flownetworks.reward.entity.RewardInfo',
#                                                       'title': 'Congratulations'},
#                                       'usageType': 'MULTI',
#                                       'value': '0'},
#                              'lastModifiedBy': 'system',
#                              'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 44, 56, 889000),
#                              'name': 'Air Pass',
#                              'status': 'Active',
#                              'type': 'Coupon'}],
#                 'rules': [{'_class': 'io.flownetworks.playbook.entity.RuleEntity',
#                            '_id': ObjectId('6081a80d2a1a9f71ca89437a'),
#                            'createdBy': 'system',
#                            'createdDate': datetime.datetime(2021, 4, 22, 16, 45, 1, 504000),
#                            'expression': '---\n'
#                                          'name: Cross-Sell Voucher Rule\n'
#                                          'description: Rule for Cross-Sell '
#                                          'Voucher\n'
#                                          'priority: 1\n'
#                                          'condition: "ActivityKind.Transaction '
#                                          '== input.kind"\n'
#                                          'actions:\n'
#                                          '  - '
#                                          '"output.add(\\"6081a8082a1a9f71ca89436d\\")"',
#                            'kind': 'Transaction',
#                            'lastModifiedBy': 'system',
#                            'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 45, 1, 504000),
#                            'name': '#3 Cross-Sell Voucher Rule'}],
#                 'startTime': datetime.datetime(2021, 6, 30, 15, 0),
#                 'status': 'Active',
#                 'type': 'Engagement'},
#                {'_class': 'io.flownetworks.playbook.entity.PlaybookEntity',
#                 'endTime': datetime.datetime(2021, 7, 31, 15, 0),
#                 'engagements': [{'_class': 'io.flownetworks.engagement.entity.EngagementEntity',
#                                  '_id': ObjectId('6081a81d2a1a9f71ca894395'),
#                                  'code': 'scratch_card',
#                                  'createdBy': 'system',
#                                  'createdDate': datetime.datetime(2021, 4, 22, 16, 45, 17, 893000),
#                                  'data': {'inProgress': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                          'description': 'Earn '
#                                                                         'more '
#                                                                         'when '
#                                                                         'you '
#                                                                         'spend. '
#                                                                         'Make '
#                                                                         '$remainingLevels '
#                                                                         'more '
#                                                                         'payment(s) '
#                                                                         'of '
#                                                                         '$minQualifyingAmount '
#                                                                         'or '
#                                                                         'more '
#                                                                         'at '
#                                                                         '$qualifyingMerchantName '
#                                                                         'to '
#                                                                         'earn '
#                                                                         '$goalRewardName',
#                                                          'title': 'Punch and '
#                                                                   'win'},
#                                           'loaded': {'_class': 'io.flownetworks.engagement.entity.EngagementInfo',
#                                                      'description': 'Earn more '
#                                                                     'when you '
#                                                                     'spend. '
#                                                                     'Make '
#                                                                     '$remainingLevels '
#                                                                     'more '
#                                                                     'payment(s) '
#                                                                     'of '
#                                                                     '$minQualifyingAmount '
#                                                                     'or more '
#                                                                     'at '
#                                                                     '$qualifyingMerchantName '
#                                                                     'to earn '
#                                                                     '$goalRewardName',
#                                                      'title': 'Punch and win'},
#                                           'termAndCondition': '<a '
#                                                               'href="http://google.com">Terms '
#                                                               '& '
#                                                               'Conditions</a>'},
#                                  'expiredInSeconds': 480,
#                                  'lastModifiedBy': 'system',
#                                  'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 45, 17, 893000),
#                                  'name': 'Scratch Card',
#                                  'scoringConversions': [{'_class': 'io.flownetworks.engagement.entity.ScoringConversionEntity',
#                                                          '_id': ObjectId('6081a81d2a1a9f71ca894394'),
#                                                          'createdBy': 'system',
#                                                          'createdDate': datetime.datetime(2021, 4, 22, 16, 45, 17, 632000),
#                                                          'lastModifiedBy': 'system',
#                                                          'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 45, 17, 632000),
#                                                          'maxScore': 1,
#                                                          'minScore': 1,
#                                                          'name': 'Scratch to '
#                                                                  'win',
#                                                          'reward': {'_class': 'io.flownetworks.reward.entity.RewardEntity',
#                                                                     '_id': ObjectId('6081a8082a1a9f71ca89436d'),
#                                                                     'createdBy': 'system',
#                                                                     'createdDate': datetime.datetime(2021, 4, 22, 16, 45, 17, 632000),
#                                                                     'data': {'discountType': 'FIXED_AMOUNT',
#                                                                              'display': {'_class': 'io.flownetworks.reward.entity.RewardDisplay',
#                                                                                          'displayName': 'Air '
#                                                                                                         'Pass '
#                                                                                                         'Voucher',
#                                                                                          'displayValue': '0'},
#                                                                              'promoCode': 'N/A',
#                                                                              'rewardCollected': {'_class': 'io.flownetworks.reward.entity.RewardInfo',
#                                                                                                  'title': 'Congratulations'},
#                                                                              'rewardReady': {'_class': 'io.flownetworks.reward.entity.RewardInfo',
#                                                                                              'title': 'Congratulations'},
#                                                                              'usageType': 'MULTI',
#                                                                              'value': '0'},
#                                                                     'lastModifiedBy': 'system',
#                                                                     'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 45, 17, 632000),
#                                                                     'name': 'Air '
#                                                                             'Pass',
#                                                                     'status': 'Active',
#                                                                     'type': 'Coupon'}}],
#                                  'type': 'ChanceBased'}],
#                 'name': 'Scratch to win',
#                 'rewardColor': '#FFE000',
#                 'rewards': [{'_class': 'io.flownetworks.reward.entity.RewardEntity',
#                              '_id': ObjectId('6081a81d2a1a9f71ca894393'),
#                              'createdBy': 'system',
#                              'createdDate': datetime.datetime(2021, 4, 22, 16, 45, 17, 124000),
#                              'data': {'discountType': 'PERCENTAGE_DISCOUNT',
#                                       'display': {'_class': 'io.flownetworks.reward.entity.RewardDisplay$RewardDisplayBuilder',
#                                                   'displayName': 'Visa GO '
#                                                                  'voucher',
#                                                   'displayValue': '5% off'},
#                                       'promoCode': 'N/A',
#                                       'rewardCollected': {'_class': 'io.flownetworks.reward.entity.RewardInfo',
#                                                           'title': 'Congratulations'},
#                                       'rewardReady': {'_class': 'io.flownetworks.reward.entity.RewardInfo',
#                                                       'title': 'Congratulations'},
#                                       'usageType': 'SINGLE',
#                                       'value': '5'},
#                              'lastModifiedBy': 'system',
#                              'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 45, 17, 124000),
#                              'name': 'Discount 5%',
#                              'status': 'Active',
#                              'type': 'Coupon'}],
#                 'rules': [{'_class': 'io.flownetworks.playbook.entity.RuleEntity',
#                            '_id': ObjectId('6081a81e2a1a9f71ca894396'),
#                            'createdBy': 'system',
#                            'createdDate': datetime.datetime(2021, 4, 22, 16, 45, 18, 157000),
#                            'expression': '---\n'
#                                          'name: Scratch Card Engagement Rule\n'
#                                          'description: Rule for Scratch Card '
#                                          'Engagement\n'
#                                          'priority: 1\n'
#                                          'condition: "ActivityKind.Transaction '
#                                          '== input.kind && '
#                                          'input.data.transaction.homeAmount >= '
#                                          '200"\n'
#                                          'actions:\n'
#                                          '  - '
#                                          '"output.add(\\"6081a81d2a1a9f71ca894395\\")"',
#                            'kind': 'Transaction',
#                            'lastModifiedBy': 'system',
#                            'lastModifiedDate': datetime.datetime(2021, 4, 22, 16, 45, 18, 157000),
#                            'name': 'Product: Scratch Card Engagement Rule'}],
#                 'startTime': datetime.datetime(2021, 6, 30, 15, 0),
#                 'status': 'Active',
#                 'type': 'Merchant'}],
#  'receiptVaultStorage': 'AWS',
#  'widgetTemplates': [{'_class': 'io.flownetworks.widget.entity.WidgetTemplateEntity',
#                       '_id': ObjectId('609015f58360c63967e735e0'),
#                       'appliedActivityOutcomeKind': 'REWARD',
#                       'displayFields': ['id:id',
#                                         'name:name',
#                                         'type:type',
#                                         'data:data',
#                                         'status:status',
#                                         'assets:assets',
#                                         'expiredAt:expiredAt'],
#                       'fields': ['id',
#                                  'name',
#                                  'type',
#                                  'data',
#                                  'status',
#                                  'assets',
#                                  'expiredAt'],
#                       'kind': 'REWARD',
#                       'lastModifiedBy': 'system',
#                       'lastModifiedDate': datetime.datetime(2021, 6, 19, 10, 26, 45, 767000)},
#                      {'_class': 'io.flownetworks.widget.entity.WidgetTemplateEntity',
#                       '_id': ObjectId('609015f68360c63967e735e2'),
#                       'displayFields': ['transaction.time:time',
#                                         'transaction.merchantCurrency:merchantCurrency',
#                                         'transaction.merchantAmount:merchantAmount',
#                                         'transaction.homeCurrency:homeCurrency',
#                                         'transaction.homeAmount:homeAmount'],
#                       'fields': ['transaction.time',
#                                  'transaction.merchantCurrency',
#                                  'transaction.merchantAmount',
#                                  'transaction.homeCurrency',
#                                  'transaction.homeAmount'],
#                       'kind': 'PAYMENT_INFO',
#                       'lastModifiedBy': 'system',
#                       'lastModifiedDate': datetime.datetime(2021, 6, 19, 10, 26, 46, 97000)},
#                      {'_class': 'io.flownetworks.widget.entity.WidgetTemplateEntity',
#                       '_id': ObjectId('609015f78360c63967e735e4'),
#                       'displayFields': ['paymentStore.location.storeName:storeName',
#                                         'paymentStore.location.address1:address1',
#                                         'paymentStore.location.address2:address2',
#                                         'paymentStore.location.city:city',
#                                         'paymentStore.location.state:state',
#                                         'paymentStore.location.zipCode:zipCode',
#                                         'paymentStore.location.countryCode:countryCode',
#                                         'paymentStore.location.longitude:longitude',
#                                         'paymentStore.location.latitude:latitude'],
#                       'fields': ['paymentStore.location.storeName',
#                                  'paymentStore.location.address1',
#                                  'paymentStore.location.address2',
#                                  'paymentStore.location.city',
#                                  'paymentStore.location.state',
#                                  'paymentStore.location.zipCode',
#                                  'paymentStore.location.countryCode',
#                                  'paymentStore.location.longitude',
#                                  'paymentStore.location.latitude'],
#                       'kind': 'MERCHANT_LOCATION',
#                       'lastModifiedBy': 'system',
#                       'lastModifiedDate': datetime.datetime(2021, 6, 19, 10, 26, 46, 111000)},
#                      {'_class': 'io.flownetworks.widget.entity.WidgetTemplateEntity',
#                       '_id': ObjectId('609015f88360c63967e735e6'),
#                       'displayFields': ['paymentSource.externalId:externalId',
#                                         'paymentSource.last4Digits:last4Digits',
#                                         'paymentSource.paymentSourceProduct:paymentSourceProduct',
#                                         'paymentSource.paymentFundingSource:paymentFundingSource',
#                                         'paymentSource.paymentSourceNetwork:paymentSourceNetwork',
#                                         'paymentSource.paymentMethod:paymentMethod'],
#                       'fields': ['paymentSource.externalId',
#                                  'paymentSource.last4Digits',
#                                  'paymentSource.paymentSourceProduct',
#                                  'paymentSource.paymentFundingSource',
#                                  'paymentSource.paymentSourceNetwork',
#                                  'paymentSource.paymentMethod'],
#                       'kind': 'PAYMENT_METHOD',
#                       'lastModifiedBy': 'system',
#                       'lastModifiedDate': datetime.datetime(2021, 6, 19, 10, 26, 46, 131000)},
#                      {'_class': 'io.flownetworks.widget.entity.WidgetTemplateEntity',
#                       '_id': ObjectId('609015fa8360c63967e735e8'),
#                       'appliedActivityOutcomeKind': 'ENGAGEMENT',
#                       'displayFields': ['id:id',
#                                         'name:name',
#                                         'expiredAt:expiredAt',
#                                         'type:type',
#                                         'url:url',
#                                         'briefUrl:briefUrl',
#                                         'progress:progress'],
#                       'fields': ['id',
#                                  'name',
#                                  'expiredAt',
#                                  'type',
#                                  'url',
#                                  'briefUrl',
#                                  'progress'],
#                       'kind': 'ENGAGEMENT',
#                       'lastModifiedBy': 'system',
#                       'lastModifiedDate': datetime.datetime(2021, 6, 19, 10, 26, 46, 160000)},
#                      {'_class': 'io.flownetworks.widget.entity.WidgetTemplateEntity',
#                       '_id': ObjectId('609015fb8360c63967e735ea'),
#                       'displayFields': ['merchantName:merchantName',
#                                         'paymentStore.mcc:mcc',
#                                         'paymentStore.mcgCode:mcgCode',
#                                         'paymentStore.mcgDescription:mcgDescription',
#                                         'mcgIcon:mcgIcon'],
#                       'fields': ['merchantName',
#                                  'paymentStore.mcc',
#                                  'paymentStore.mcgCode',
#                                  'paymentStore.mcgDescription',
#                                  'mcgIcon'],
#                       'kind': 'MERCHANT_INFO',
#                       'lastModifiedBy': 'system',
#                       'lastModifiedDate': datetime.datetime(2021, 6, 19, 10, 26, 46, 177000)}]}
